# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My\ Drive
# %cd broutanlab_course/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/broutanlab_course

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
import dlib
from imutils import face_utils

# %%
face_classifier = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# %%
img = cv2.imread('pic1.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_classifier.detectMultiScale(gray, 1.2, 6)

# %%
if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    rect = dlib.rectangle(left = x,top=y, right=x+w, bottom=y+h)
    shape = predictor(gray, rect)
    shape = face_utils.shape_to_np(shape)
    cv2.rectangle(img, (x,y), (x+w,y+h), (0, 255, 0), 2)
    for (x, y) in shape:
      cv2.circle(img, (x, y), 1, (0, 0, 255), -1)
    cv2_imshow(img)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7FD85CA149D0>

# %%
img = cv2.imread('pic2.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
faces = face_classifier.detectMultiScale(gray, 1.2, 6)

# %%
if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    rect = dlib.rectangle(left = x,top=y, right=x+w, bottom=y+h)
    shape = predictor(gray, rect)
    shape = face_utils.shape_to_np(shape)
    cv2.rectangle(img, (x,y), (x+w,y+h), (0, 255, 0), 2)
    for (x, y) in shape:
      cv2.circle(img, (x, y), 1, (0, 0, 255), -1)
cv2_imshow(img)
cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=625x417 at 0x7FD85B123BD0>
