# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My\ Drive
# %cd broutanlab_course/
# Out:
# Mounted at /content/drive
# /content/drive/My Drive
# /content/drive/My Drive/broutanlab_course

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
img = cv2.imread('pic1.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7F82A2B1A1D0>

# %%
faces = face_cascade.detectMultiScale(gray, 1.2, 6)
if faces is ():
    print("No faces found")

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(127,0,255),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
cv2_imshow(img)
cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7F82A22B9BE0>

# %%
img = cv2.imread('pic2.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
faces = face_cascade.detectMultiScale(gray, 1.2, 6)
if faces is ():
    print("No faces found")

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(127,0,255),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
cv2_imshow(img)
cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=625x417 at 0x7F82A22B9898>
# <PIL.Image.Image image mode=RGB size=625x417 at 0x7F82A22B9390>

# %%
img = cv2.imread('pic3.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
faces = face_cascade.detectMultiScale(gray, 1.037, 7)
if faces is ():
    print("No faces found")

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(127,0,255),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(255,255,0),2)
cv2_imshow(img)
cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=720x400 at 0x7F82A22B5240>
# <PIL.Image.Image image mode=RGB size=720x400 at 0x7F82A22B5208>
