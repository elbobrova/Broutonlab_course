# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd drive/My\ Drive
# %cd broutanlab_course/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# [Errno 2] No such file or directory: 'drive/My Drive'
# /content/drive/My Drive/broutanlab_course
# [Errno 2] No such file or directory: 'broutanlab_course/'
# /content/drive/My Drive/broutanlab_course

# %%
import numpy as np
import cv2
from google.colab.patches import cv2_imshow

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

# %%
img = cv2.imread('pic1.png')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7F4D8178CB70>

# %%
faces = face_cascade.detectMultiScale(gray, 1.2, 6)
if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (127,0,255), 2)
    cv2_imshow(img)
    cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x7F4D8178DE10>

# %%
img = cv2.imread('pic2.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
faces = face_cascade.detectMultiScale(gray, 1.2, 6)
if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (127,0,255), 2)
cv2_imshow(img)
cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=625x417 at 0x7F4D8178CA20>
# <PIL.Image.Image image mode=RGB size=625x417 at 0x7F4D8178CA58>

# %%
img = cv2.imread('pic3.jpg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(img)
faces = face_cascade.detectMultiScale(gray, 1.0474, 5)
if faces is ():
    print("No faces found")
for (x,y,w,h) in faces:
    cv2.rectangle(img, (x,y), (x+w,y+h), (127,0,255), 2)
cv2_imshow(img)
cv2.waitKey(0)
    
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=720x400 at 0x7F4D817A9DD8>
# <PIL.Image.Image image mode=RGB size=720x400 at 0x7F4D817A9D30>
